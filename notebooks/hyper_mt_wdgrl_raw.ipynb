# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from hyper_raw_ploter import disc_raw_plot, src_trg_raw_plot, wasserstein_raw_plot,\
wasserstein_valid_raw_plot, losses_raw_plot

sns.set(style="whitegrid", palette="muted", color_codes=True)

# %%
logdir = '../log/'
hyper_name = 'gamma'
data_folder = os.path.join(logdir, f'micro_tcga_wdgrl_{hyper_name}_2020-10-01_18-50-59')

# %%
# read meta data
meta_df = pd.read_csv(os.path.join(data_folder, 'meta'), 
                      index_col=0, header=0, names=['param', 'folder'])
meta_df
# Out:
#       param    folder
# 0     0.000  Watcher0
# 1     0.001  Watcher1
# 2     0.010  Watcher2
# 3     0.100  Watcher3
# 4     1.000  Watcher4
# 5    10.000  Watcher5
# 6   100.000  Watcher6
# 7  1000.000  Watcher7

# %%
n_params = meta_df.shape[0]
raw_figsize = (7*n_params, 7)

# %% [markdown]
# ### Discriminator

# %%
disc_raw_plot(data_folder, meta_df)

# %% [markdown]
# ## WDGRL Micorarray -> TCGA

# %% [markdown]
# ### Training

# %%
src_trg_raw_plot(data_folder, 'train', meta_df, param_name=hyper_name)
wasserstein_raw_plot(data_folder, 'train', meta_df, gr_ylim=(-0.01, 0.1), 
                 wd_ylim=(-0.5, 3), param_name=hyper_name)
losses_raw_plot(data_folder, 'train', meta_df, param_name=hyper_name)

# %% [markdown]
# ### Validation

# %%
src_trg_raw_plot(data_folder, 'valid', meta_df, param_name=hyper_name)
wasserstein_valid_raw_plot(data_folder, 'valid', meta_df, wd_ylim=(-0.5, 3), param_name=hyper_name)
losses_raw_plot(data_folder, 'valid', meta_df, param_name=hyper_name)
